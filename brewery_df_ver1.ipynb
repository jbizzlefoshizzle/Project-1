# %%
import pandas as pd
import numpy as np

# %%
address = "Addresses.csv"

# %%
address_data = pd.read_csv(address)
address_data.columns = ['brewery', 'address']
address_data
# Out:
#                                                brewery  \
# 0                                    2Kids Brewing Co.
# 1                             13 Point Brewing Company
# 2                                 32 North Brewing Co.
# 3                                Abnormal Beer Company
# 4                             AleSmith Brewing Company
# 5                                    Align Brewing Co.
# 6                                  Alpine Beer Company
# 7                                  Amplified Ale Works
# 8                                  Amplified Ale Works
# 9                                   Arcana Brewing Co.
# 10                                    Attitude Brewing
# 11                           Automatic Brewing Company
# 12                               Aztec Brewing Company
# 13                                 Back Street Brewery
# 14                                  Bagby Beer Comapny
# 15    Ballast Point Brewing & Spirits - Home Brew Mart
# ...
