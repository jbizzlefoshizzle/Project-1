# %%
from brewerydb import *
from config import api_key
import requests

# %%
BreweryDb.configure(api_key, DEFAULT_BASE_URI)

# %%
sd_ingredients = BreweryDb.ingredients({'geo':1,
                         'lat':32.7157,
                         'lng':117.1611,
                         'radius':30,
                         'units':'m'})

# %%
sd_ingredients
# Can someone turn this into a dataframe?
# Out:
# {'currentPage': 1,
#  'numberOfPages': 3,
#  'totalResults': 134,
#  'data': [{'id': 1532,
#    'name': 'Abbey Ale',
#    'category': 'yeast',
#    'categoryDisplay': 'Yeast',
#    'createDate': '2012-01-03 02:41:39'},
#   {'id': 166,
#    'name': 'Acidulated Malt',
#    'category': 'malt',
#    'categoryDisplay': 'Malts, Grains & Fermentables',
#    'createDate': '2012-01-03 02:41:34',
#    'updateDate': '2012-04-16 16:59:09'},
#   {'id': 1,
#    'name': 'Admiral',
#    'description': 'Bred at Wye as a replacement for Target and released in 1998, Admiral is a high-alpha variety considered to have a more pleasing, less harsh bitterness.',
#    'category': 'hop',
#    'categoryDisplay': 'Hops',
#    'createDate': '2012-01-03 02:41:33',
#    'updateDate': '2013-04-10 16:32:12'},
#   {'id': 4,
#    'name': 'Amarillo',
# ...

# %%
sd_ingredients["data"][0]["name"]
sd_ingredients["data"][0]["category"]
sd_ingredients["data"][1]["name"]
# Out:
# 'Acidulated Malt'
