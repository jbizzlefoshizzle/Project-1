# %%
# Dependencies
import pandas as pd
import numpy as np
from config import api_key
import requests
import json
import matplotlib.pyplot as plt

# %%
# Create a dataframe of all award-winning beers since 2009
csv_data = "beer_winners.csv"

all_winner_data = pd.read_csv(csv_data)
all_winner_data.columns = ['medal', 'beer_name','brewery',
                       'city','county','state',
                       'category','year','total_category_entries']
all_winner_data.head()
# Out:
#   medal           beer_name                           brewery       city  \
# 0  Gold    Milwaukee’s Best                Miller Brewing Co.     Golden
# 1  Gold   County Seat Wheat  Blind Tiger Brewery & Restaurant     Topeka
# 2  Gold  Haywire Hefeweizen                 Pyramid Breweries    Seattle
# 3  Gold     Raspberry Creek            Breakwater Brewing Co.  Oceanside
# 4  Gold      Stillwater Rye               Montana Brewing Co.   Billings
#
#       county state                              category  year  \
# 0  Jefferson    CO     American-Style Cream Ale or Lager  2009
# 1      Mason    KS             American-Style Wheat Beer  2009
# 2       King    WA  American-Style Wheat Beer With Yeast  2009
# 3  San Diego    CA              Fruit Beer or Field Beer  2009
# 4  Christian    MT      Herb and Spice or Chocolate Beer  2009
#
#    total_category_entries
# 0                      24
# 1                      19
# 2                      43
# 3                     104
# 4                      85

# %% [markdown]
# ## How many beers brewed in California have won a medal?

# %%
ca = all_winner_data[all_winner_data['state'] == 'CA']
ca.reset_index(inplace=True)
ca_number = ca['index'].count()
print(f'There have been {ca_number} award-winning* beers in California in the last decade.')
cal_data = ca.drop(columns=['index'],axis=1)
cal_data = cal_data.sort_values('year', ascending=False)
cal_data.reset_index(inplace=True)
cal_data = cal_data.drop(columns=['index'],axis=1)
cal_data.head()
# Out:
# There have been 553 award-winning* beers in California in the last decade.
#     medal      beer_name                                 brewery         city  \
# 0  Bronze        Eclipse                  FiftyFifty Brewing Co.      Truckee
# 1  Silver       STS Pils  Russian River Brewing Co. - Production   Santa Rosa
# 2    Gold   The Coachman                     Societe Brewing Co.    San Diego
# 3    Gold  Santa's Brass                     Drake's Brewing Co.  San Leandro
# 4  Silver         Märzen                     Sudwerk Brewing Co.        Davis
#
#       county state                            category  year  \
# 0     Nevada    CA  Wood- and Barrel-Aged Strong Stout  2018
# 1       Pima    CA           Kellerbier or Zwickelbier  2018
# 2  San Diego    CA              Session India Pale Ale  2018
# 3    Alameda    CA   Wood- and Barrel-Aged Strong Beer  2018
# 4       Yolo    CA          American-Style Amber Lager  2018
#
#    total_category_entries
# 0                     177
# 1                      67
# 2                      92
# 3                     162
# 4                      91

# %% [markdown]
# ## How many beers brewed in San Diego have won a medal?

# %%
temp = cal_data[cal_data['county'] == 'San Diego']
temp.reset_index(inplace=True)
sd_number = temp['index'].count()
print(f'There have been {sd_number} award-winning* beers in San Diego in the last decade.')
sd_data = temp.drop(columns=['index'], axis=1)
sd_data = sd_data.sort_values('year', ascending=False)
sd_data.reset_index(inplace=True)
sd_data = sd_data.drop(columns=['index'],axis=1)
sd_data.head()
# Out:
# There have been 148 award-winning* beers in San Diego in the last decade.
#     medal        beer_name                            brewery          city  \
# 0    Gold     The Coachman                Societe Brewing Co.     San Diego
# 1  Silver             Oats            Pizza Port Solana Beach  Solana Beach
# 2  Silver  Duck Duck Gooze  Port Brewing Co. / The Lost Abbey    San Marcos
# 3  Silver           Redrum              Duck Foot Brewing Co.     San Diego
# 4  Silver      Noble Miner                   Burgeon Beer Co.      Carlsbad
#
#       county state                         category  year  \
# 0  San Diego    CA           Session India Pale Ale  2018
# 1  San Diego    CA                    Oatmeal Stout  2018
# 2  San Diego    CA  Wood- and Barrel-Aged Sour Beer  2018
# 3  San Diego    CA       Wood- and Barrel-Aged Beer  2018
# 4  San Diego    CA                     Session Beer  2018
#
#    total_category_entries
# 0                      92
# 1                      59
# 2                      76
# 3                      77
# 4                      50

# %% [markdown]
# ## In terms of medals won, what are the top 5 breweries in San Diego?

# %%
medals_sd = sd_data.groupby(['brewery'])['medal'].count()
top_brew_sd = medals_sd.sort_values(ascending=False)
top_5_sd = top_brew_sd.head()
top_5_sd
# Out:
# brewery
# Pizza Port Carlsbad        24
# AleSmith Brewing Co.       10
# The Lost Abbey              9
# Pizza Port Solana Beach     8
# Pizza Port Ocean Beach      7
# Name: medal, dtype: int64

# %% [markdown]
# ## In terms of medals won, what are the top 5 breweries in California?

# %%
medals_cal = cal_data.groupby(['brewery'])['medal'].count()
top_brew_cal = medals_cal.sort_values(ascending=False)
top_5_cal = top_brew_cal.head()
top_5_cal
# Out:
# brewery
# Firestone Walker Brewing Co.    28
# Pizza Port Carlsbad             24
# Pabst Brewing Co.               12
# Pizza Port Ocean Beach          12
# Beachwood BBQ & Brewing         11
# Name: medal, dtype: int64

# %% [markdown]
# ## Why is there a discrepancy between the San Diego list and the California list?
# ### Let's find out!

# %%
pizza_port = all_winner_data[all_winner_data['brewery'] == 'Pizza Port Ocean Beach']
pizza_port = pizza_port.sort_values('year', ascending=False)
pizza_port.reset_index(inplace=True)
pizza_port = pizza_port.drop(columns=['index'],axis=1)
pizza_port
# Out:
#      medal                      beer_name                 brewery  \
# 0     Gold                      Guillaume  Pizza Port Ocean Beach
# 1   Bronze                 Bacon and Eggs  Pizza Port Ocean Beach
# 2   Bronze                      Guillaume  Pizza Port Ocean Beach
# 3   Silver                      Guillaume  Pizza Port Ocean Beach
# 4   Bronze                La Flama Dorada  Pizza Port Ocean Beach
# 5     Gold                    Beer Hunter  Pizza Port Ocean Beach
# 6   Silver                   Rhino Chaser  Pizza Port Ocean Beach
# 7   Bronze                  Kung Fu Elvis  Pizza Port Ocean Beach
# 8     Gold             Skidmark Brown Ale  Pizza Port Ocean Beach
# 9   Silver  Rhino Chaser Imperial Red Ale  Pizza Port Ocean Beach
# 10  Bronze                    Z-Man Stout  Pizza Port Ocean Beach
# 11  Silver                 Skidmark Brown  Pizza Port Ocean Beach
#
#            city     county state                        category  year  \
# 0     San Diego  San Diego    CA                    Session Beer  2017
# 1     San Diego  San Diego    CA                     Coffee Beer  2015
# 2     San Diego  San Diego    CA                    Session Beer  2015
# 3   Ocean Beach    Suffolk    CA                    Session Beer  2014
# 4   Ocean Beach    Suffolk    CA            Belgian-Style Tripel  2014
# 5   Ocean Beach    Suffolk    CA                    Session Beer  2013
# 6   Ocean Beach    Suffolk    CA                Imperial Red Ale  2013
# 7   Ocean Beach    Suffolk    CA  American-Style Strong Pale Ale  2013
# 8     San Diego  San Diego    CA          English-Style Mild Ale  2011
# 9     San Diego  San Diego    CA                Imperial Red Ale  2011
# 10    San Diego  San Diego    CA             Foreign-Style Stout  2011
# 11    San Diego  San Diego    CA          English-Style Mild Ale  2010
#
#     total_category_entries
# 0                       40
# 1                      149
# 2                       44
# 3                       94
# 4                       58
# 5                       56
# 6                       56
# 7                      120
# 8                       25
# 9                       57
# 10                      23
# 11                      27

# %% [markdown]
# ## Now for the big question:
# ## What are the top 5 breweries in the United States?

# %%
medals_us = all_winner_data.groupby(['brewery'])['medal'].count()
top_brew_us = medals_us.sort_values(ascending=False)
top_5_us = top_brew_us.head()
top_5_us
# Out:
# brewery
# Firestone Walker Brewing Co.    28
# Pizza Port Carlsbad             24
# Sun King Brewing Co.            19
# Pabst Brewing Co.               19
# Chuckanut Brewery               18
# Name: medal, dtype: int64

# %%
# ^^^
# Maybe we might want to speak on the fact that
# Firestone is in SLO and Pizza Port Carlsbad is in SD County?

# %%
# Create a dataframe?
# Possible visualization ideas?
# Possible state-by-state breakdown of medals? Using a different groupby?
# Even see the mean of all US states medal counts and compare it to CA? <-- I like this idea the best so far, myself

sd_medals = sd_data.groupby(['medal'])['year'].count()
ca_medals = cal_data.groupby(['medal'])['year'].count()
all_medals = all_winner_data.groupby(['medal'])['year'].count()
print('all SD medals')
print(sd_medals)
print("")
print('all CA medals')
print(ca_medals)
print("")
print('all US medals')
print(all_medals)

# medals_df = pd.DataFrame('sd_metals','ca_medals','all_medals')
# medals_df
# Out:
# all SD medals
# medal
# Bronze    49
# Gold      58
# Silver    41
# Name: year, dtype: int64
#
# all CA medals
# medal
# Bronze    186
# Gold      185
# Silver    182
# Name: year, dtype: int64
#
# all US medals
# medal
# Bronze    886
# Gold      878
# Silver    882
# Name: year, dtype: int64

# %%
means_us = all_winner_data.groupby(['category'])['total_category_entries'].mean()
means_us.head(10)
# Out:
# category
# Aged Beer                                    33.2
# American Style Amber Lager                   45.0
# American Style Amber/Red Ale                 78.0
# American Style Brown Ale                     43.0
# American Style Light Lager                   25.0
# American Style Pale Ale                     108.0
# American Style Specialty Lager               23.0
# American-Belgo-Style Ale                     60.7
# American-Style Amber Lager                   58.0
# American-Style Amber Lager or Dark Lager    108.0
# Name: total_category_entries, dtype: float64

# %%
means_cal = cal_data.groupby(['category'])['total_category_entries'].mean()
means_cal.head(10)
# Out:
# category
# Aged Beer                                    34.333333
# American Style Amber/Red Ale                 78.000000
# American Style Brown Ale                     43.000000
# American-Belgo-Style Ale                     63.375000
# American-Style Amber Lager                   69.500000
# American-Style Amber Lager or Dark Lager    108.000000
# American-Style Amber/Red Ale                 96.363636
# American-Style Black Ale                     63.625000
# American-Style Brett Beer                    38.000000
# American-Style Brown Ale                     75.142857
# Name: total_category_entries, dtype: float64

# %%
means_sd = sd_data.groupby(['category'])['total_category_entries'].mean()
means_sd.head(10)
# Out:
# category
# American Style Amber/Red Ale       78.000000
# American Style Brown Ale           43.000000
# American-Belgo-Style Ale           70.333333
# American-Style Amber/Red Ale       99.333333
# American-Style Black Ale           73.000000
# American-Style Brown Ale           69.666667
# American-Style India Black Ale     53.000000
# American-Style India Pale Ale     235.000000
# American-Style Pale Ale           157.500000
# American-Style Sour Ale            53.400000
# Name: total_category_entries, dtype: float64

# %%
# Possibly a line graph? Or scatter-plot?

# total_entries_us = all_winner_data.groupby(['year'])['total_category_entries'].count()
# print('total US entries')
# print(total_entries_us)
# total_entries_cal = cal_data.groupby(['year'])['total_category_entries'].count()
# print("")
# print('total CA entries')
# print(total_entries_cal)
total_entries_sd = sd_data.groupby(['year'])['total_category_entries'].count()
print("")
print('total SD entries')
print(total_entries_sd) # bar or scatter


sd_data2 = sd_data.sort_values('year', ascending=True)
year = sd_data2["year"].unique()
print(year)

# x = year
y = total_entries_sd
ticks = []
for i in year:
    ticks.append(i)

plt.bar(year, y, facecolor="blue", alpha=0.75, align="center")

# plt.plot(year, y, color="blue", linewidth=5)

plt.xticks(ticks)
plt.title("San Diego Entry Winners", size=18)
plt.xlabel("Years", size=14)
plt.ylabel("Count of SD Entries", size=14)
# plt.grid(True)
plt.show()
# Out:
# total SD entries
# year
# 2009    14
# 2010    15
# 2011    18
# 2012    14
# 2013     8
# 2014    12
# 2015    19
# 2016    18
# 2017    14
# 2018    16
# Name: total_category_entries, dtype: int64
# [2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]

# %%
# List of all award-winning beers in 2018
# Any ides for visualization and/or story-telling?

bweh = sd_data.loc[sd_data['year'] == 2018]
sd_2018 = bweh[['medal', 'beer_name', 'brewery', 'category', 'total_category_entries']]
sd_2018
# Out:
#      medal                         beer_name  \
# 0     Gold                      The Coachman
# 1   Silver                              Oats
# 2   Silver                   Duck Duck Gooze
# 3   Silver                            Redrum
# 4   Silver                       Noble Miner
# 5   Bronze                         Bird Park
# 6   Bronze                          Know Ego
# 7   Bronze                Rail Gun Wee Heavy
# 8   Silver            Delaminator Doppelbock
# 9   Bronze                    Zungen Brecher
# 10    Gold               B.Right On Pale Ale
# 11    Gold      Natural Bridge: Vienna Lager
# 12    Gold                          Rye Dawn
# 13  Bronze     Chocolate Macadamia Nut Stout
# 14    Gold                         Liquid AC
# 15  Silver  Groundswell Piloncillo Brown Ale
#
#                                 brewery                            category  \
# 0                   Societe Brewing Co.              Session India Pale Ale
# 1               Pizza Port Solana Beach                       Oatmeal Stout
# 2     Port Brewing Co. / The Lost Abbey     Wood- and Barrel-Aged Sour Beer
# 3                 Duck Foot Brewing Co.          Wood- and Barrel-Aged Beer
# 4                      Burgeon Beer Co.                        Session Beer
# 5                   North Park Beer Co.             Bohemian-Style Pilsener
# 6               Groundswell Brewing Co.       Classic Irish-Style Dry Stout
# 7          BNS Brewing & Distilling Co.               Old Ale or Strong Ale
# 8                   Rip Current Brewery  German-Style Doppelbock or Eisbock
# 9                      Home Brewing Co.                     Historical Beer
# 10                  Ocean Beach Brewery             American-Style Pale Ale
# 11                        Eppig Brewing                        Session Beer
# 12               Breakwater Brewing Co.                            Rye Beer
# 13                     Kilowatt Brewing                      Chocolate Beer
# 14  Karl Strauss Brewing Co. - La Jolla            English-Style Summer Ale
# 15              Groundswell Brewing Co.            American-Style Brown Ale
#
#     total_category_entries
# 0                       92
# 1                       59
# 2                       76
# 3                       77
# 4                       50
# 5                       84
# 6                       54
# 7                       37
# 8                       31
# 9                       38
# 10                     170
# 11                      50
# 12                      57
# 13                      59
# 14                      61
# 15                      76

# %%
# POSSIBLE DATA VISUALIZATION FOR THIS LIST?
# ***How many award-winning beers does each brewery have?***

# Maybe a pie chart showing the medal breakdown of SD breweries?
# Or a pie chart showing the top 5-7 breweries, with all the others listed as "Other"

# Maybe combine similar names (i.e. "Ballast Point Brewing Co" and "Ballast Point Brewing Co.")
top_brew_sd
# Out:
# brewery
# Pizza Port Carlsbad                                       24
# AleSmith Brewing Co.                                      10
# The Lost Abbey                                             9
# Pizza Port Solana Beach                                    8
# Pizza Port Ocean Beach                                     7
# Green Flash Brewing Co.                                    6
# Port Brewing Co.                                           6
# BNS Brewing & Distilling Co.                               4
# Rip Current Brewery                                        4
# Karl Strauss Brewing Co. - La Jolla                        4
# Karl Strauss Brewing Co.                                   4
# Societe Brewing Co.                                        4
# Ballast Point Brewing & Spirits - Scripps Ranch            3
# Stone Brewing World Bistro & Gardens - Liberty Station     3
# Bagby Beer Co.                                             3
# Breakwater Brewing Co.                                     3
# Second Chance Beer Co.                                     3
# Karl Strauss Brewing Co. - San Diego                       3
# Benchmark Brewing Co.                                      2
# Duck Foot Brewing Co.                                      2
# Stone Brewing Co.                                          2
# Groundswell Brewing Co.                                    2
# Ballast Point Brewing Co.                                  2
# New English Brewing Co.                                    2
# Culture Brewing Co.                                        2
# Eppig Brewing                                              1
# Ballast Point Brewing Co                                   1
# Alpine Beer Co.                                            1
# Coronado Brewing Company Brewpub                           1
# Brit Antrim Benefit Beer Pizza Port Ocean Beach            1
# Ballast Point Brewing Co. - Home Brew Mart                 1
# Burgeon Beer Co.                                           1
# URBN St. Brewing Co.                                       1
# Home Brewing Co.                                           1
# Karl Strauss Brewing Co. - Carlsbad                        1
# The Beer Co.                                               1
# SouthNorte Beer Co.                                        1
# South Park Brewing - CA                                    1
# Saint Archer Brewing Co.                                   1
# Rock Bottom Brewery - La Jolla                             1
# Pure Project                                               1
# Port Brewing Co. / The Lost Abbey                          1
# Pizza Port Bressi Ranch                                    1
# Oceanside Ale Works                                        1
# Ocean Beach Brewery                                        1
# OB Brewery                                                 1
# North Park Beer Co.                                        1
# Mother Earth Brew Co.                                      1
# Monkey Paw Brewing                                         1
# Kilowatt Brewing                                           1
# Monkey Paw Brewing Co.                                     1
# Name: medal, dtype: int64

# %%
df = all_winner_data

# %% [markdown]
# ### Plot - Total Entries Over Past 10 Years

# %%
# Adding "key" column to remove dupes for total entries per year
df["key"] = df["category"] + df["year"].map(str)
# df
unq_entry_count = df.drop_duplicates(subset="key", keep="first")
year_grp = unq_entry_count.groupby("year")
# year_grp.describe()

entries_sum = year_grp["total_category_entries"].sum()
year = year_grp["year"].unique()

x_axis = year
y_axis = entries_sum
tick_locs = []
for x in x_axis:
    tick_locs.append(x)

# Testing plots
# plt.bar(x_axis, y_axis, facecolor="blue", alpha=0.75, align="center")

plt.plot(x_axis, y_axis, color="blue", linewidth=5)

plt.xticks(tick_locs)
plt.title("Entries Over Past Decade", size=18)
plt.xlabel("Years", size=14)
plt.ylabel("Total Number of Entries", size=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Testing Plot for # Categories Over the Years

# %%
category_count = year_grp["category"].count()
# category_count
y_axis = category_count

plt.plot(x_axis, y_axis, color="blue", linewidth=5)
# plt.bar(x_axis, y_axis, facecolor="blue", alpha=0.75, align="center")

plt.xticks(tick_locs)
plt.title("Number of Categories Over Past Decade", size=18)
plt.xlabel("Years", size=14)
plt.ylabel("Total Number of Categories", size=14)
plt.ylim(74, 105)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Most Popular Beer Category by Entries

# %%
df2 = df[["year","category","total_category_entries","key"]].copy()
# df2.count() #2646
unq_df2 = df2.drop_duplicates(subset="key", keep="first")
unq_df2 = unq_df2.drop(["key"],axis=1)
unq_df2.head()
# Out:
#    year                              category  total_category_entries
# 0  2009     American-Style Cream Ale or Lager                      24
# 1  2009             American-Style Wheat Beer                      19
# 2  2009  American-Style Wheat Beer With Yeast                      43
# 3  2009              Fruit Beer or Field Beer                     104
# 4  2009      Herb and Spice or Chocolate Beer                      85

# %%
df_agg = unq_df2.groupby(["year","category"]).agg({"total_category_entries":sum})

# %%
a=df_agg["total_category_entries"].groupby(level=0,group_keys=False)

# %%
top_3 = a.nlargest(3)
top_3
# Out:
# year  category
# 2009  American-Style India Pale Ale         134
#       Wood- and Barrel-Aged Strong Beer     110
#       American Style Pale Ale               108
# 2010  American-Style India Pale Ale         142
#       American-Style Pale Ale               109
#       Imperial India Pale Ale                97
# 2011  American-Style India Pale Ale         176
#       Wood- and Barrel-Aged Strong Beer     118
#       American-Style Pale Ale               105
# 2012  American-Style India Pale Ale         203
#       Imperial India Pale Ale               128
#       Herb and Spice Beer                   114
# 2013  American-Style India Pale Ale         252
#       Imperial India Pale Ale               149
#       Herb and Spice Beer                   134
# 2014  American-Style India Pale Ale         279
#       Herb and Spice Beer                   150
#       American-Style Pale Ale               145
# 2015  American-Style India Pale Ale         336
#       Imperial India Pale Ale               208
#       Wood- and Barrel-Aged Strong Beer     179
# 2016  American-Style India Pale Ale         312
#       Imperial India Pale Ale               211
#       American-Style Strong Pale Ale        169
# 2017  American-Style India Pale Ale         408
#       Imperial India Pale Ale               221
#       American-Style Pale Ale               199
# 2018  Juicy or Hazy India Pale Ale          391
#       American-Style India Pale Ale         311
#       Wood- and Barrel-Aged Strong Stout    177
# Name: total_category_entries, dtype: int64
